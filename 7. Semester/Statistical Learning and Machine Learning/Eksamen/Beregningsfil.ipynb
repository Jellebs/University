# %% [markdown]
# # Mine beregninger til reeksamen 2026

# %%
import numpy as np

# %% [markdown]
# Setup:

# %%
x   = np.array([ 0.1,  0.2])[:, np.newaxis]
w_1 = np.array([[0.1,  0.2], 
                [-1.1, 1.2], 
                [-2.1, 2.2]])
w_2 = np.array([[-0.1],
                [ 1.1], 
                [ 2.2]])

# %%
h1 = lambda x : ...
h2 = lambda x : ...

# %%
a_1 = w_1.T @ x # np.vstack([1, x])         tilføj bias? 
z_1 = h1(a_1)   
a_2 = w_2.T @ z_1 # np.vstack([1, z_1])     tilføj bias?
y_k = h2(a_2)
