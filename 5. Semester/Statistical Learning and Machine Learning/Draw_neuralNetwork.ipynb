# %% [markdown]
#  You are given a set of data points $xi ∈ \R 8, i = 1,...,N$, each followed by a five-dimensional target $t_i ∈ \R 5, i = 1,...,N.$
#  You want to use a feedforward neural network formed by three hidden-layers for solving this regression problem

# %% [markdown]
# # 1 Describe which are the parameters and the hyper-parameters of the neural network. Use appropriate mathematical symbols (e.g., matrices, functions).

# %%
#Kør lige 'pip install nnv' først i jeres conda cmd, hvis i ikke har nnv installeret i forvejen
from nnv import NNV
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (200,10)   # Change default figure size
layersList = [  #Define your network architecture here
    {"title":"input\n(relu)", "units": 8, "color": "darkBlue"},
    {"title":"hidden 1\n(relu)", "units": 5},
    {"title":"hidden 2\n(relu)", "units": 2},
    {"title":"hidden 3\n(relu)", "units": 6},
    {"title":"output \n Linear", "units": 5,"color": "darkBlue"},
]
NNV(layersList,max_num_nodes_visible=8, node_radius=5, spacing_layer=30, font_size=30).render() #Render the network
# Out:
# (<Figure size 20000x1000 with 1 Axes>, <Axes: >)
